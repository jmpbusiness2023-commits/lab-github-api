# %%
# GitHub Profile Analyzer
from git_api import main

url = "http://127.0.0.1:5000"

username = main()
# Out:
# GitHub Profile Information:
# Name: Jeremy PATOLE
# Bio: New Student at Iron Hack
# Public Repos: 41
# Followers: 0
# Following: 0
# Location: Paris
# Blog:
#
# Public Repositories:
# - git-practice: https://github.com/jmpbusiness2023-commits/git-practice (⭐ 0)
# - lab-dw-data-aggregation-and-filtering: https://github.com/jmpbusiness2023-commits/lab-dw-data-aggregation-and-filtering (⭐ 0)
# - lab-dw-data-cleaning-and-formatting: https://github.com/jmpbusiness2023-commits/lab-dw-data-cleaning-and-formatting (⭐ 0)
# - lab-dw-data-structuring-and-combining: https://github.com/jmpbusiness2023-commits/lab-dw-data-structuring-and-combining (⭐ 0)
# - lab-dw-pandas: https://github.com/jmpbusiness2023-commits/lab-dw-pandas (⭐ 0)
# - lab-eda-bivariate: https://github.com/jmpbusiness2023-commits/lab-eda-bivariate (⭐ 0)
# - lab-eda-univariate: https://github.com/jmpbusiness2023-commits/lab-eda-univariate (⭐ 0)
# - lab-ensemble: https://github.com/jmpbusiness2023-commits/lab-ensemble (⭐ 0)
# ...
