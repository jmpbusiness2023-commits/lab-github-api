# %%
# GitHub Profile Analyzer
from git_api import main

url = "http://127.0.0.1:5000"

username = main()
# Out:
# GitHub Profile: jmpbusiness2023-commits
# Name: Jeremy PATOLE
# Username: jmpbusiness2023-commits
# Bio: New Student at Iron Hack
# Public Repos: 42
# Followers: 0
# Following: 0
# Location: Paris
# Profile URL: https://github.com/jmpbusiness2023-commits
#
# Repositories ---------------------
# - git-practice
# View Repo (URL): https://github.com/jmpbusiness2023-commits/git-practice
# Stars: 0, Forks: 0
# Language: None
# Last Updated: 2025-09-26T13:02:34Z
#
#
# - lab-dw-data-aggregation-and-filtering
# View Repo (URL): https://github.com/jmpbusiness2023-commits/lab-dw-data-aggregation-and-filtering
# Stars: 0, Forks: 0
# Language: Jupyter Notebook
# Last Updated: 2025-10-17T00:35:49Z
#
#
# - lab-dw-data-cleaning-and-formatting
# View Repo (URL): https://github.com/jmpbusiness2023-commits/lab-dw-data-cleaning-and-formatting
# Stars: 0, Forks: 0
# Language: Jupyter Notebook
# Last Updated: 2025-10-15T23:17:07Z
#
#
# - lab-dw-data-structuring-and-combining
# ...
